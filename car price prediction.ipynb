# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Car-Price-Prediction" data-toc-modified-id="Car-Price-Prediction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Car Price Prediction</a></span><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Overview-of-the-dataset" data-toc-modified-id="Overview-of-the-dataset-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Overview of the dataset</a></span></li><li><span><a href="#Column-info:" data-toc-modified-id="Column-info:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Column info:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Checking-for-null-values-in-the-dataset:" data-toc-modified-id="Checking-for-null-values-in-the-dataset:-1.3.0.1"><span class="toc-item-num">1.3.0.1&nbsp;&nbsp;</span>Checking for null values in the dataset:</a></span></li></ul></li><li><span><a href="#Data-preparation:" data-toc-modified-id="Data-preparation:-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Data preparation:</a></span></li></ul></li></ul></li><li><span><a href="#Univariate-analysyis" data-toc-modified-id="Univariate-analysyis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Univariate analysyis</a></span><ul class="toc-item"><li><span><a href="#Car_ID" data-toc-modified-id="Car_ID-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Car_ID</a></span></li><li><span><a href="#Symboling" data-toc-modified-id="Symboling-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Symboling</a></span></li><li><span><a href="#Fueltype" data-toc-modified-id="Fueltype-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Fueltype</a></span></li><li><span><a href="#Aspiration" data-toc-modified-id="Aspiration-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Aspiration</a></span></li><li><span><a href="#Door-number" data-toc-modified-id="Door-number-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Door number</a></span></li><li><span><a href="#Carbody" data-toc-modified-id="Carbody-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Carbody</a></span></li><li><span><a href="#Drivewheel" data-toc-modified-id="Drivewheel-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Drivewheel</a></span></li><li><span><a href="#Enginelocation" data-toc-modified-id="Enginelocation-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Enginelocation</a></span></li><li><span><a href="#Wheelbase" data-toc-modified-id="Wheelbase-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Wheelbase</a></span></li><li><span><a href="#Carlength" data-toc-modified-id="Carlength-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Carlength</a></span></li><li><span><a href="#Carwidth" data-toc-modified-id="Carwidth-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Carwidth</a></span></li><li><span><a href="#Curbweight" data-toc-modified-id="Curbweight-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Curbweight</a></span></li><li><span><a href="#Engine-type" data-toc-modified-id="Engine-type-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Engine type</a></span></li><li><span><a href="#Cylinder-number" data-toc-modified-id="Cylinder-number-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Cylinder number</a></span></li><li><span><a href="#Engine-size" data-toc-modified-id="Engine-size-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Engine size</a></span></li><li><span><a href="#Fuel-system" data-toc-modified-id="Fuel-system-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Fuel system</a></span></li><li><span><a href="#Bore-ratio" data-toc-modified-id="Bore-ratio-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Bore ratio</a></span></li><li><span><a href="#Stroke" data-toc-modified-id="Stroke-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Stroke</a></span></li><li><span><a href="#Compression-ratio" data-toc-modified-id="Compression-ratio-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Compression ratio</a></span></li><li><span><a href="#Horse-power" data-toc-modified-id="Horse-power-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Horse power</a></span></li><li><span><a href="#Peak-rpm" data-toc-modified-id="Peak-rpm-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Peak rpm</a></span></li><li><span><a href="#City-mileage" data-toc-modified-id="City-mileage-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>City mileage</a></span></li><li><span><a href="#Highway-mileage" data-toc-modified-id="Highway-mileage-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Highway mileage</a></span></li><li><span><a href="#Price" data-toc-modified-id="Price-2.24"><span class="toc-item-num">2.24&nbsp;&nbsp;</span>Price</a></span></li><li><span><a href="#Company-name" data-toc-modified-id="Company-name-2.25"><span class="toc-item-num">2.25&nbsp;&nbsp;</span>Company name</a></span></li></ul></li><li><span><a href="#Bivariate-analysis" data-toc-modified-id="Bivariate-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Bivariate analysis</a></span><ul class="toc-item"><li><span><a href="#Symboling-vs-Price" data-toc-modified-id="Symboling-vs-Price-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Symboling vs Price</a></span></li><li><span><a href="#Fuel-type-vs-Price" data-toc-modified-id="Fuel-type-vs-Price-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Fuel type vs Price</a></span></li><li><span><a href="#Aspiration-vs-Price" data-toc-modified-id="Aspiration-vs-Price-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Aspiration vs Price</a></span></li><li><span><a href="#Number-of-doors-vs-Price" data-toc-modified-id="Number-of-doors-vs-Price-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Number of doors vs Price</a></span></li><li><span><a href="#Carbody-vs-Price" data-toc-modified-id="Carbody-vs-Price-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Carbody vs Price</a></span></li><li><span><a href="#Drive-wheel-vs-Price" data-toc-modified-id="Drive-wheel-vs-Price-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Drive wheel vs Price</a></span></li><li><span><a href="#Engine-location-vs-Price" data-toc-modified-id="Engine-location-vs-Price-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Engine location vs Price</a></span></li><li><span><a href="#Wheelbase-vs-Price" data-toc-modified-id="Wheelbase-vs-Price-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Wheelbase vs Price</a></span></li><li><span><a href="#Car-length-vs-Price" data-toc-modified-id="Car-length-vs-Price-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Car length vs Price</a></span></li><li><span><a href="#Car-width-vs-Price" data-toc-modified-id="Car-width-vs-Price-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Car width vs Price</a></span></li><li><span><a href="#Car-height-vs-Price" data-toc-modified-id="Car-height-vs-Price-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Car height vs Price</a></span></li><li><span><a href="#Curb-weight-vs-Price" data-toc-modified-id="Curb-weight-vs-Price-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Curb weight vs Price</a></span></li><li><span><a href="#Engine-type-vs-Price" data-toc-modified-id="Engine-type-vs-Price-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Engine type vs Price</a></span></li><li><span><a href="#Cylinder-number-vs-Price" data-toc-modified-id="Cylinder-number-vs-Price-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Cylinder number vs Price</a></span></li><li><span><a href="#Engine-size-vs-Price" data-toc-modified-id="Engine-size-vs-Price-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Engine size vs Price</a></span></li><li><span><a href="#Fuel-system-vs-Price" data-toc-modified-id="Fuel-system-vs-Price-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>Fuel system vs Price</a></span></li><li><span><a href="#Bore-ratio-vs-Price" data-toc-modified-id="Bore-ratio-vs-Price-3.17"><span class="toc-item-num">3.17&nbsp;&nbsp;</span>Bore ratio vs Price</a></span></li><li><span><a href="#Stroke-vs-Price" data-toc-modified-id="Stroke-vs-Price-3.18"><span class="toc-item-num">3.18&nbsp;&nbsp;</span>Stroke vs Price</a></span></li><li><span><a href="#Compression-ratio-vs-Price" data-toc-modified-id="Compression-ratio-vs-Price-3.19"><span class="toc-item-num">3.19&nbsp;&nbsp;</span>Compression ratio vs Price</a></span></li><li><span><a href="#Horsepower-vs-Price" data-toc-modified-id="Horsepower-vs-Price-3.20"><span class="toc-item-num">3.20&nbsp;&nbsp;</span>Horsepower vs Price</a></span></li><li><span><a href="#Peak-rpm-vs-Price" data-toc-modified-id="Peak-rpm-vs-Price-3.21"><span class="toc-item-num">3.21&nbsp;&nbsp;</span>Peak rpm vs Price</a></span></li><li><span><a href="#Mileage-vs-Price" data-toc-modified-id="Mileage-vs-Price-3.22"><span class="toc-item-num">3.22&nbsp;&nbsp;</span>Mileage vs Price</a></span></li><li><span><a href="#Company-name-vs-Price" data-toc-modified-id="Company-name-vs-Price-3.23"><span class="toc-item-num">3.23&nbsp;&nbsp;</span>Company name vs Price</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#The-variables-which-influence-price-are:" data-toc-modified-id="The-variables-which-influence-price-are:-3.23.0.1"><span class="toc-item-num">3.23.0.1&nbsp;&nbsp;</span>The variables which influence price are:</a></span></li></ul></li></ul></li><li><span><a href="#Multivariate-analysis" data-toc-modified-id="Multivariate-analysis-3.24"><span class="toc-item-num">3.24&nbsp;&nbsp;</span>Multivariate analysis</a></span></li></ul></li><li><span><a href="#Conclusion:" data-toc-modified-id="Conclusion:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusion:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Fuel-type" data-toc-modified-id="1.-Fuel-type-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>1. Fuel type</a></span></li><li><span><a href="#2.-Aspiration" data-toc-modified-id="2.-Aspiration-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>2. Aspiration</a></span></li><li><span><a href="#3.-Car-body" data-toc-modified-id="3.-Car-body-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span>3. Car body</a></span></li><li><span><a href="#4.-Drive-wheel" data-toc-modified-id="4.-Drive-wheel-4.0.0.4"><span class="toc-item-num">4.0.0.4&nbsp;&nbsp;</span>4. Drive wheel</a></span></li><li><span><a href="#5.-Engine-location" data-toc-modified-id="5.-Engine-location-4.0.0.5"><span class="toc-item-num">4.0.0.5&nbsp;&nbsp;</span>5. Engine location</a></span></li><li><span><a href="#6.-Car-length" data-toc-modified-id="6.-Car-length-4.0.0.6"><span class="toc-item-num">4.0.0.6&nbsp;&nbsp;</span>6. Car length</a></span></li><li><span><a href="#7.-Car-width" data-toc-modified-id="7.-Car-width-4.0.0.7"><span class="toc-item-num">4.0.0.7&nbsp;&nbsp;</span>7. Car width</a></span></li><li><span><a href="#8.-Curb-weight" data-toc-modified-id="8.-Curb-weight-4.0.0.8"><span class="toc-item-num">4.0.0.8&nbsp;&nbsp;</span>8. Curb weight</a></span></li><li><span><a href="#9.-Engine-type" data-toc-modified-id="9.-Engine-type-4.0.0.9"><span class="toc-item-num">4.0.0.9&nbsp;&nbsp;</span>9. Engine type</a></span></li><li><span><a href="#10.-Cylinder-number" data-toc-modified-id="10.-Cylinder-number-4.0.0.10"><span class="toc-item-num">4.0.0.10&nbsp;&nbsp;</span>10. Cylinder number</a></span></li><li><span><a href="#11.-Engine-size" data-toc-modified-id="11.-Engine-size-4.0.0.11"><span class="toc-item-num">4.0.0.11&nbsp;&nbsp;</span>11. Engine size</a></span></li><li><span><a href="#12.-Fuel-system" data-toc-modified-id="12.-Fuel-system-4.0.0.12"><span class="toc-item-num">4.0.0.12&nbsp;&nbsp;</span>12. Fuel system</a></span></li><li><span><a href="#13.-Bore-ratio" data-toc-modified-id="13.-Bore-ratio-4.0.0.13"><span class="toc-item-num">4.0.0.13&nbsp;&nbsp;</span>13. Bore ratio</a></span></li><li><span><a href="#14.-Horsepower" data-toc-modified-id="14.-Horsepower-4.0.0.14"><span class="toc-item-num">4.0.0.14&nbsp;&nbsp;</span>14. Horsepower</a></span></li><li><span><a href="#15.-Fuel-economy" data-toc-modified-id="15.-Fuel-economy-4.0.0.15"><span class="toc-item-num">4.0.0.15&nbsp;&nbsp;</span>15. Fuel economy</a></span></li><li><span><a href="#16.-Company-name" data-toc-modified-id="16.-Company-name-4.0.0.16"><span class="toc-item-num">4.0.0.16&nbsp;&nbsp;</span>16. Company name</a></span></li><li><span><a href="#17.-Wheelbase" data-toc-modified-id="17.-Wheelbase-4.0.0.17"><span class="toc-item-num">4.0.0.17&nbsp;&nbsp;</span>17. Wheelbase</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Car Price Prediction

# %% [markdown]
# ## Problem Statement
#
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
#
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
#    - Which variables are significant in predicting the price of a car
#    - How well those variables describe the price of a car
#
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.

# %%
#reading file
df=pd.read_csv('D:/downloads/CarPrice_Assignment.csv')

# %%
#checking the number of rows and columns in the dataset.
df.shape
# Out:
# (205, 26)

# %% [markdown]
# ## Overview of the dataset

# %%
#checking the first five rows of the dataset.
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
# ...

# %% [markdown]
# ## Column info:
# *The dataset has the following columns,*
# ![image.png](attachment:image.png)
# The dataset consists of 205 rows and 26 columns.

# %% [markdown]
# #### Checking for null values in the dataset:

# %%
#checking null values in the dataset
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %% [markdown]
# ### Data preparation:
# deriving a new column,

# %%
#new column is derived from carname and is named as compname
new = df["CarName"].str.split(" ", n = 1, expand = True) 
df["CompName"]= new[0]

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase     ...       fuelsystem  \
# 0  convertible        rwd          front       88.6     ...             mpfi
# 1  convertible        rwd          front       88.6     ...             mpfi
# 2    hatchback        rwd          front       94.5     ...             mpfi
# 3        sedan        fwd          front       99.8     ...             mpfi
# 4        sedan        4wd          front       99.4     ...             mpfi
#
# ...

# %% [markdown]
# We have successfully derived a column from CarName and named it CompName. We no longer require car name as it is given in the question that we must select Company name as the independent variable, let us drop carName variable.

# %%
#dropping carname column
df=df.drop(['CarName'],axis=1)

# %% [markdown]
# # Univariate analysyis

# %% [markdown]
# Let us go through each of the independent variable present in the dataset and check which variable influences the change in price of the car.
#
# The variables present in the dataset can be broadly classified into two types of variables namely categorical and numeric variables.
#
# For categorical variables distplot and countplot are used as plots since the distribution can easily be visualised through the various categories present in the dataset.
#
# For numeric variables scatter plot is used which shows the distribution of data through the range of data present in the dataset. Further the value of alpha is adjusted so that the area where most of the dataset is concentrated is clearly visible.

# %% [markdown]
# ## Car_ID

# %% [markdown]
# car_id is a number given to the car which is taken in the dataset. It doesnt influence the price variable in any way. It can be dropped from the dataset.

# %%
#dropping car id column
df=df.drop(['car_ID'],axis=1)

# %% [markdown]
# ## Symboling

# %% [markdown]
# Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)

# %%
df['symboling'].describe()
# Out:
# count    205.000000
# mean       0.834146
# std        1.245307
# min       -2.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000
# Name: symboling, dtype: float64

# %%
df['symboling'].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
#plot to check the distribution in symboling
sns.countplot(df['symboling']);

# %% [markdown]
# - We can see that most of the cars come under 0 symboling which they are neither risky nor safe.
# - But we also observe that there are more values on right of 0, which means most of the cars in production are risky.

# %% [markdown]
# ## Fueltype

# %% [markdown]
# Describes which type of fuel the car uses.

# %%
df['fueltype'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
#plot to check the type of fuel used in cars
sns.countplot(x='fueltype',data=df);

# %% [markdown]
# - We can clearly see that the car uses either gas or diesel as fuel.
# - But diesel cars are less in number when compared to gas fuel cars.

# %%
df['fueltype'].describe()
# Out:
# count     205
# unique      2
# top       gas
# freq      185
# Name: fueltype, dtype: object

# %% [markdown]
# ## Aspiration

# %%
df['aspiration'].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
#plot to check categorical distribution of aspiration
sns.countplot(x='aspiration',data=df)

# %% [markdown]
# - More cars use std as aspiration.

# %% [markdown]
# ## Door number

# %%
df['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
#plot to check distribution of doors in car
sns.countplot(x='doornumber',data=df)

# %% [markdown]
# - We can find more number of four door cars than 2 door cars but the difference between them is very less.

# %% [markdown]
# ## Carbody

# %%
df['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %% [markdown]
# There are 5 types of carbody used,

# %%
#plot to check type of car body
sns.countplot(x='carbody',data=df);

# %% [markdown]
# - Sedan is the carbody most companies make followed by hatchback.
# - Wagon, convertible and hardtop constitute very less in number.

# %% [markdown]
# ## Drivewheel

# %%
df['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
#plot to check the drive wheel in car
sns.set(style="darkgrid")
sns.countplot(x='drivewheel',data=df);

# %% [markdown]
# - The drivewheel in cars is of 3 categories namely fwd, rwd and 4wd.
# - Out of these fwd is the most used and 4wd is the least.

# %%
df['drivewheel'].describe()
# Out:
# count     205
# unique      3
# top       fwd
# freq      120
# Name: drivewheel, dtype: object

# %% [markdown]
# ## Enginelocation

# %%
df['enginelocation'].value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
sns.countplot(x='enginelocation',data=df,palette='gnuplot_r');

# %% [markdown]
# - Only 3 instances of rear engine cars are found.
# - The data is skewed with front engine having very high frequency.

# %%
df['enginelocation'].describe()
# Out:
# count       205
# unique        2
# top       front
# freq        202
# Name: enginelocation, dtype: object

# %% [markdown]
# ## Wheelbase

# %%
df['wheelbase'].describe()
# Out:
# count    205.000000
# mean      98.756585
# std        6.021776
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheelbase, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["wheelbase"], bins=range(86,120, 4),kde=False,color=(0.7, 0.3, 0))
plt.xlabel("wheelbase")
plt.show()

# %% [markdown]
# - We can see that most of the wheelbase of car is between 94 and 98.

# %% [markdown]
# ## Carlength

# %%
df["carlength"].describe()
# Out:
# count    205.000000
# mean     174.049268
# std       12.337289
# min      141.100000
# 25%      166.300000
# 50%      173.200000
# 75%      183.100000
# max      208.100000
# Name: carlength, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["carlength"], bins=range(141,210, 5),color=(0, 0.3, 0))
plt.xlabel("car length")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most of the cars have length between 170 to 180 units.
# - The curve appears like a uniform distribution curve symettric around 170.

# %% [markdown]
# ## Carwidth

# %%
df["carwidth"].describe()
# Out:
# count    205.000000
# mean      65.907805
# std        2.145204
# min       60.300000
# 25%       64.100000
# 50%       65.500000
# 75%       66.900000
# max       72.300000
# Name: carwidth, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["carwidth"], bins=range(60,75, 2),color=(0.7, 0.3, 0))
plt.xlabel("car width")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most cars have width of 64 to 66 units.

# %% [markdown]
# ## Curbweight

# %%
df["curbweight"].describe()
# Out:
# count     205.000000
# mean     2555.565854
# std       520.680204
# min      1488.000000
# 25%      2145.000000
# 50%      2414.000000
# 75%      2935.000000
# max      4066.000000
# Name: curbweight, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["curbweight"], bins=range(1480,4066, 250),color=(0.1, 0.1, 0))
plt.xlabel("curb weight")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most of the cars in the given data have the curb weight of 1750 - 2000.
# - The graph appears like a bell curve with a slight right skewness.

# %% [markdown]
# ## Engine type

# %%
df['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df['enginetype'].describe()
# Out:
# count     205
# unique      7
# top       ohc
# freq      148
# Name: enginetype, dtype: object

# %%
sns.countplot(df['enginetype'],palette='rainbow');

# %% [markdown]
#  - Most of the cars have ohc type engines.
#  - The next popular engine in cars are dohc, ohcv, I and ohcf which have the same frequency but occurence is very less when compared to ohc engines.
#  - Rotor and dohcv engines are negligible in the given data.

# %% [markdown]
# ## Cylinder number

# %%
df['cylindernumber'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df['cylindernumber'].describe()
# Out:
# count      205
# unique       7
# top       four
# freq       159
# Name: cylindernumber, dtype: object

# %%
sns.countplot(df['cylindernumber'],palette='rainbow');

# %% [markdown]
# - Most of the cars have 4 cylinders followed by 6.
# - Other number of cylinders are rarely used.

# %% [markdown]
# ## Engine size

# %%
df['enginesize'].describe()
# Out:
# count    205.000000
# mean     126.907317
# std       41.642693
# min       61.000000
# 25%       97.000000
# 50%      120.000000
# 75%      141.000000
# max      326.000000
# Name: enginesize, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["enginesize"], bins=range(61,326, 25),color=(0.4, 0.7, 0))
plt.xlabel("engine size")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most of the cars have engine size of 100.
# - The distribution is right skewed.

# %% [markdown]
# ## Fuel system

# %%
df['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# spfi     1
# mfi      1
# Name: fuelsystem, dtype: int64

# %%
df['fuelsystem'].describe()
# Out:
# count      205
# unique       8
# top       mpfi
# freq        94
# Name: fuelsystem, dtype: object

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['fuelsystem'],palette='rainbow');

# %% [markdown]
# - Most of the cars have mpfi fuel type followed by 2bbl.
# - Other types constitute to only 20% of cars.

# %% [markdown]
# ## Bore ratio

# %%
df['boreratio'].describe()
# Out:
# count    205.000000
# mean       3.329756
# std        0.270844
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.580000
# max        3.940000
# Name: boreratio, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.stripplot(df["boreratio"],jitter=True,alpha=0.35)
plt.xlabel("bore ratio")
plt.show()

# %% [markdown]
# - We can see that most of the cars have bore ratio in the range of 3.2 to 3.6.

# %% [markdown]
# ## Stroke

# %%
df['stroke'].describe()
# Out:
# count    205.000000
# mean       3.255415
# std        0.313597
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.stripplot(df["stroke"],jitter=True,alpha=0.4,dodge= True)
plt.xlabel("stroke ")
plt.show()

# %% [markdown]
#  - We can see that most of the cars have stroke value between 3 to 3.5

# %% [markdown]
# ## Compression ratio

# %%
df['compressionratio'].describe()
# Out:
# count    205.000000
# mean      10.142537
# std        3.972040
# min        7.000000
# 25%        8.600000
# 50%        9.000000
# 75%        9.400000
# max       23.000000
# Name: compressionratio, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["compressionratio"], bins=range(5,25, 1),color=(0.4, 0.7, 0),kde=False)
plt.xlabel("compression ratio")
plt.show()

# %% [markdown]
# - Most cars have compression ratio 10.
# - Cars with compression ratio between 7.5 to 9 are also abundant, but very less cars have compression ratio between 21 to 23

# %% [markdown]
# ## Horse power

# %%
df['horsepower'].describe()
# Out:
# count    205.000000
# mean     104.117073
# std       39.544167
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["horsepower"], bins=range(45,290, 20),color=(0.4, 0.7, 0))
plt.xlabel("horse power")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most cars have horse power of 60 to 100.
# - Very few cars have horse power more than 150.

# %% [markdown]
# ## Peak rpm

# %%
df['peakrpm'].describe()
# Out:
# count     205.000000
# mean     5125.121951
# std       476.985643
# min      4150.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6600.000000
# Name: peakrpm, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["peakrpm"], bins=range(4000,7000, 250),color=(0.4, 0.7, 0),kde=False)
plt.xlabel("peak rpm")
plt.show()

# %% [markdown]
# - Most cars have peak rpm between 4800 to 5200.
# - The next found highest frequency is around 5600 to 5800 rpm.

# %% [markdown]
# ## City mileage

# %%
df['citympg'].describe()
# Out:
# count    205.000000
# mean      25.219512
# std        6.542142
# min       13.000000
# 25%       19.000000
# 50%       24.000000
# 75%       30.000000
# max       49.000000
# Name: citympg, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["citympg"], bins=range(10,50, 5),color=(0.4, 0.7, 0))
plt.xlabel("city mileage")
plt.show()
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - The mileage of cars is distributed evenly between 15 to 35 units.
# - Very few cars have mileage above 40.

# %% [markdown]
# ##  Highway mileage

# %%
df['highwaympg'].describe()
# Out:
# count    205.000000
# mean      30.751220
# std        6.886443
# min       16.000000
# 25%       25.000000
# 50%       30.000000
# 75%       34.000000
# max       54.000000
# Name: highwaympg, dtype: float64

# %%
plt.figure(figsize=(10,5));
sns.distplot(df["highwaympg"], bins=range(10,55, 5),color=(0.4, 0.7, 0));
plt.xlabel("highway mileage");
plt.show();
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - It is same as that of city mileage with some constant addition of 5 along all the ranges as observed through the graphs.
# - The cars have mileage equally distributed between 20 to 40 units.

# %% [markdown]
# ## Price

# %%
df['price'].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.stripplot(df["price"],jitter=True,alpha=0.4,dodge= True)
plt.xlabel("price of car")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["price"], bins=range(5000,46000, 500),color=(0.4, 0.7, 0));
# Out:
# C:\Users\vinu6\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Most of the cars have price between 5000 to 10000 which are the budget and easily affordable cars.
# - The next group of most found cars are between the price range 10000 to 20000.
# - There are very less cars beyong 20000 price bracket.
# - The data is right skewed.

# %% [markdown]
# ## Company name

# %%
df['CompName'].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# jaguar          3
# alfa-romero     3
# chevrolet       3
# maxda           2
# renault         2
# vw              2
# toyouta         1
# mercury         1
# vokswagen       1
# Nissan          1
# porcshce        1
# Name: CompName, dtype: int64

# %% [markdown]
# - We can observe that some of the company names have been written with a spelling mistake or different spelling thus leading to distributed frequency while calculting. These distributed numbers must be made to come under the same unique name.

# %%
#function to replace names
def replace_name(a,b):
    df.CompName.replace(a,b,inplace=True)

replace_name('maxda','mazda')
replace_name('porcshce','porsche')
replace_name('toyouta','toyota')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

# %%
df['CompName'].describe()
# Out:
# count        205
# unique        23
# top       toyota
# freq          32
# Name: CompName, dtype: object

# %%
plt.figure(figsize=(25,15))
sns.countplot(df['CompName'])

# %% [markdown]
# - We can observe that toyota produces the most cars.

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# Let us check how the columns vary with price

# %%
#columns that are present after univariate analysis
df.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth     ...       fuelsystem  \
# 0          front       88.6      168.8      64.1     ...             mpfi
# 1          front       88.6      168.8      64.1     ...             mpfi
# 2          front       94.5      171.2      65.5     ...             mpfi
# 3          front       99.8      176.6      66.2     ...             mpfi
# 4          front       99.4      176.6      66.4     ...             mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
#functions to check bivariate analysis

#for numeric data
def scatter(x): 
    plt.scatter(df[x],df['price'],alpha=0.4)
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)
    
#for categorical data    
def box(x):    
    plt.figure(figsize = (10,5)) 
    plt.title(x+' vs Price')
    sns.boxplot(x=df[x], y=df.price, palette=("cubehelix"))

# %% [markdown]
# ## Symboling vs Price

# %%
#box plot for symboling vs price
box('symboling')

# %% [markdown]
# - -1 symboling cars have the most price
# - 3 and -2 symboling cars have the same price though risk is high in the latter.
# - 1 and 2 symboling cars have less price.

# %% [markdown]
# ## Fuel type vs Price

# %%
box('fueltype')

# %% [markdown]
# - Diesel cars have high price when compared to the gas cars.
# - There are many values outside the whiskers in gas boxplot.

# %% [markdown]
# ## Aspiration vs Price

# %%
box('aspiration')

# %% [markdown]
# - Turbo aspiration has more price than std aspiration which can be clearly observed by looking at the mean price and whiskers of the barplot.
# - Std aspiration consists of many outliers.

# %% [markdown]
# ## Number of doors vs Price

# %%
box('doornumber')

# %% [markdown]
# - The number of doors doesn't effect the price as both two and four door cars have approximately equal price.

# %% [markdown]
# ## Carbody vs Price

# %%
box('carbody')

# %% [markdown]
# - Hardtop and convertible have higher prices.
# - Lot of variation can be seen in hardtop price.

# %% [markdown]
# ## Drive wheel vs Price

# %%
box('drivewheel')

# %% [markdown]
# - Rwd drive wheel has more price when compared to the other 2 drive wheel types.

# %% [markdown]
# ## Engine location vs Price

# %%
box('enginelocation')

# %% [markdown]
# - Cars having engine in rear location have more price than when is in the front location.

# %% [markdown]
# ## Wheelbase vs Price

# %%
#scatter plot for wheelbase vs price
scatter('wheelbase')

# %% [markdown]
# - Price of the car increases with increase in wheelbase meaning that both have a positive correlation

# %% [markdown]
# ## Car length vs Price

# %%
scatter('carlength')

# %% [markdown]
# - Car length has positive correlation with price

# %% [markdown]
# ## Car width vs Price

# %%
scatter('carwidth')

# %% [markdown]
# - Car width also has positive correlation with price

# %% [markdown]
# ## Car height vs Price

# %%
scatter('carheight')

# %% [markdown]
# - No relation between car height and price

# %% [markdown]
# ## Curb weight vs Price

# %%
scatter('curbweight')

# %% [markdown]
# - Positive correlation between curb weight and price

# %% [markdown]
# ## Engine type vs Price

# %%
box('enginetype')

# %% [markdown]
# - Ohcv engine has the highest price and highest range.
# - Dohcv is present only in one car but the price is high.

# %% [markdown]
# ## Cylinder number vs Price

# %%
box('cylindernumber')

# %% [markdown]
# - Cars with eight cylinders has the highest price followed by six cylinders.
# - Cars with twelve cylinder occur only once in the dataset but the price is quite high.

# %% [markdown]
# ## Engine size vs Price

# %%
scatter('enginesize')

# %% [markdown]
# - Engine size has positive correlation with price

# %% [markdown]
# ## Fuel system vs Price

# %%
box('fuelsystem')

# %% [markdown]
# - Mpfi and idi have the highest prices.

# %% [markdown]
# ## Bore ratio vs Price

# %%
scatter('boreratio')

# %% [markdown]
# - Positive correlation is found

# %% [markdown]
# ## Stroke vs Price

# %%
scatter('stroke')

# %% [markdown]
# - No significant relation

# %% [markdown]
# ## Compression ratio vs Price

# %%
scatter('compressionratio')

# %% [markdown]
# - No significant relation

# %% [markdown]
# ## Horsepower vs Price

# %%
scatter('horsepower')

# %% [markdown]
# - Positive correlation between horsepower and price

# %% [markdown]
# ## Peak rpm vs Price

# %%
scatter('peakrpm')

# %% [markdown]
# - No significant relation
#
# ## Mileage vs Price
#
# the city mileage and highway mileage are rather related variables and will be nearly equal. Thus we can use any one to compare the trend followed by price with the two mileages, but there is a factor known as fuel economy wihich takes both city mileage and highway mileage to check the approx milage of the car. this factor can be used to check the relation with price

# %%
# fuel economy is calculated by using city mileage and highway mileage
df['fueleconomy'] = (0.55 * df['citympg']) + (0.45 * df['highwaympg'])

# %%
scatter('fueleconomy')

# %% [markdown]
# - we can observe that fuel economy has negative correlation with price

# %% [markdown]
# ## Company name vs Price

# %%
#boxplot of company name vs price of car
plt.rcParams['figure.figsize']=(20,10)
sns.boxplot(x='CompName',y='price',data=df)
plt.title('Company Name vs Average Price')
plt.show()

# %%
#barplot with company name against average car price
plot1= pd.DataFrame(df.groupby(['CompName'])['price'].mean().sort_values(ascending = False))
plot1.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

# %% [markdown]
# - The average price of the car is highest for jaguar.
# - The car price depends on the company brand name.
# - A large variance is found in bmw and buick car prices.

# %% [markdown]
# #### The variables which influence price are:
#
# 1. fuel type
# 2. aspiration
# 3. car body
# 4. drive wheel
# 5. engine location
# 6. car length
# 7. car width
# 8. curb weight
# 9. engine type
# 10. cylinder number
# 11. engine size
# 12. fuel system
# 13. bore ratio
# 14. horse power
# 15. fuel economy
# 16. company name
# 17. wheelbase

# %%
#taking all the variables which infuence car price into a dataframe
car=df[['fueltype', 'aspiration', 'carbody','wheelbase',
       'drivewheel', 'enginelocation', 'carlength', 'carwidth',
        'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
       'fuelsystem', 'boreratio' ,'horsepower',
       'price', 'CompName', 'fueleconomy']]

# %%
#pairplot of all variables in the dataframe car
sns.pairplot(car)
plt.show()

# %% [markdown]
# ## Multivariate analysis

# %%
#bar plot for multivariate analysis
plt.rcParams['figure.figsize']=(20,10)
car = pd.DataFrame(df.groupby(['fuelsystem','drivewheel','carbody'])['price'].mean().unstack(fill_value=0))
car.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %% [markdown]
# - We can observe that idi fuelsystem with rwd drive wheel and hardtop car body has the highest average price.
# - The combination of rwd and mpfi or rwd idi has medium to high price range  for all type of carbody.

# %%
#bar plot for multivariate analysis
plt.rcParams['figure.figsize']=(20,10)
car = pd.DataFrame(df.groupby(['enginetype','fuelsystem'])['price'].mean().unstack(fill_value=0))
car.plot.bar()
plt.title('engine type,drivewheel vs Average price')
plt.show()

# %% [markdown]
# - We can clearly see that mpfi fuelsystem combined with dohcv has more price than any other combination. It beats other fuelsystem in every combination with engine type except in ohc where ifi is priced more than mpfi.
# - 2bbl is the least priced fuelsystem

# %%
#scatter plot for multivariate analysis
plt.figure(figsize=(8,6))

plt.title('Car width vs Horsepower')
sns.scatterplot(x=df['wheelbase'],y=df['horsepower'],hue=df['fueltype']);
plt.xlabel('Car width')
plt.ylabel('horsepower')

plt.show()

# %%
#scatter plot for multivariate analysis
plt.figure(figsize=(8,6))

plt.title('Car width vs Horsepower')
sns.scatterplot(x=df['carwidth'],y=df['horsepower'],hue=df['fueltype']);
plt.xlabel('Car width')
plt.ylabel('horsepower')

plt.show()

# %%
#scatter plot for multivariate analysis
plt.figure(figsize=(8,6))

plt.title('Car width vs Horsepower')
sns.scatterplot(x=df['wheelbase'],y=df['price'],hue=df['fueltype']);
plt.xlabel('Car width')
plt.ylabel('horsepower')

plt.show()

# %% [markdown]
# We can observe that cars using diesel as fuel has less horsepower when making a plot against the car width. Its the same case against wheelbase of the car also.
#
# But the same case doesnt occur in the case of price where both fuel type cars are distributed evenly.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# The main objective of the given problem was to find what factors effect the price of the car.
#
# After performing analysis on the given dataset, we found out that out of 26 given variables only 17 variables effect the price of cars, they are:
# #### 1. Fuel type
#
#
# - Fuel type effects the price of the car, we found out that for diesel cars the price is higher than gas cars buts gas cars are more in number than diesel cars. This may be because of pollution norms in US.
#
#
# #### 2. Aspiration
#
#
# - We found out that std aspiration cars are high in number when compared to turbo aspiration. The Price of cars with turbo aspiration is higher than that with std aspiration.
#
#
# #### 3. Car body
#
#
# - There are 5 types of car body out of which sedan and hatchback are the mostly used carbodies. The most priced car body is hardtop followed by convertible. sedans also have high prices but when looked at the average price of sedan, it falls short of average price for a hard top.
#
#
# #### 4. Drive wheel
#
#
# - There are 3 types of drive wheel out of which rwd and fwd are the most used and the price of cars containing rwd is high when compared to cars having other 2 drive wheels.
#
#
# #### 5. Engine location
#
#
# - Engine is located either in the front or rear. Only 3 instances of engine being in the rear are found in the dataset but the prices for the same are higher than average price of front engine cars thus leading to the conclusion that it is an important factor in pricing of the car.
#
#
# #### 6. Car length
#
#
# - Car length is an important factor in pricing of the car as we have seen that the price of the car increases with the increase in car length.
#
#
# #### 7. Car width
#
#
# - Car width is an important factor in pricing of the car as we have seen that the price of the car increases with the increase in car width.
#
#
# #### 8. Curb weight
#
#
# - Curb weight also positive correlation with price. Most of the cars have around 2250 curbweight.
#
#
# #### 9. Engine type
#
#
# - dohcv engine has the highest price followed by dohc engine. There are mainly 7 types of engine types in cars in the given dataset and the difference between cars with each of engine is very high.
#
#
# #### 10. Cylinder number
#
#
# - Most of the cars have 4 cylinders. But the prize of 8 cylinder and 6 cylinder cars is high.
#
#
# #### 11. Engine size
#
#
# - Most of the cars have engine size of 100 and the price of the car has a positive correlation with engine size.
#
#
# #### 12. Fuel system
#
#
# - There are mainly 8 types of fuel system in which mfi and idi are high priced. More number of mfi cars are found in US.
#
#
# #### 13. Bore ratio
#
#
# - The bore ratio between 3.2 and 3.6 is commonly found in cars. The price increases with increase in bore ratio.
#
#
# #### 14. Horsepower
#
# - Horsepower is an important factor for the price of the car. Though most of the cars have 50 to 100 horsepower, horsepower of nearly 300 can also be found. The higher the horsepower, the higher the price of the car.
#
#
# #### 15. Fuel economy
#
#
# - Fuel economy is found out by using both city and highway mileage. Fuel economy has negative correlation with price and also negative correlation with horsepower.
#
#
# #### 16. Company name
#
#
# - Company name or brand name plays an important part in price of the car. The brand which is well established and produces luxury cars have higher average car price. Toyota produces the most cars and jaguar has the highest average price per car.
#
#
# #### 17. Wheelbase
#
#
# - Most cars have wheelbase of 95 to 98 units and the wheelbase has positive correlation with price of the car.
